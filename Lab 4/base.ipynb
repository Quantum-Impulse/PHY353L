# %%
# import libraries for data vizualization and analysis
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import altair as alt
from scipy.integrate import solve_ivp
import plotly.graph_objects as go

# %%
# read trail 5 data

# useful data without the ND filter
df_3 = pd.read_csv('./Experiments_Results_Raw/3-21-24_249nm - 359nm_recording1.csv', sep='\t')
df_4 = pd.read_csv('./Experiments_Results_Raw/3-21-24_365nm - 375nm_recording1.csv', sep='\t')
df_5 = pd.read_csv('./Experiments_Results_Raw/3-21-24_431nm - 440nm_recording1.csv', sep='\t')
df_6 = pd.read_csv('./Experiments_Results_Raw/3-21-24_546nm_recording1.csv', sep='\t')
df_7 = pd.read_csv('./Experiments_Results_Raw/3-21-24_548nm_recording1.csv', sep='\t')
df_8 = pd.read_csv('./Experiments_Results_Raw/3-21-24_580nm_recording1.csv', sep='\t')

# ND filter data
df_ND1 = pd.read_csv('./Experiments_Results_Raw/3-21-24_580nm_ND_0_3(good)_1.csv', sep='\t')
df_ND1 = pd.read_csv('./Experiments_Results_Raw/3-21-24_580nm_ND_0_5(good)_1.csv', sep='\t')
df_ND1 = pd.read_csv('./Experiments_Results_Raw/3-21-24_580nm_ND_0_9(good)_1.csv', sep='\t')

# %%
# graph data of df_1
fig, ax = plt.subplots()
ax.plot(df_3['applied voltage (volts)'], df_3['measured current (nanoamps)'], label='Trail 1') 
ax.set_xlabel('Voltage (V)')
ax.set_ylabel('Current (nA)')
ax.set_title('Trail 5 Data')
plt.show()

# %%
# graph df_8 
fig, ax = plt.subplots()
ax.plot(df_8['applied voltage (volts)'], df_8['measured current (nanoamps)'], label='Trail 1')
ax.set_xlabel('Voltage (V)')
ax.set_ylabel('Current (nA)')
ax.set_title('Trail 5 Data')
plt.show()
